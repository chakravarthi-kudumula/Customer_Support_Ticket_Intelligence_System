# %% [markdown]
# # Phase 4: Embeddings + Semantic Search
#
# This notebook demonstrates semantic complaint retrieval using SBERT sentence embeddings.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.append(str(PROJECT_ROOT))

import pandas as pd
from src.retrieval.semantic_search import search

# %% [markdown]
# ## Embedding Manifest

# %%
manifest = pd.read_json(PROJECT_ROOT / 'artifacts' / 'embeddings' / 'latest_embedding_manifest.json', typ='series')
manifest

# %% [markdown]
# ## Example Query

# %%
results = search('My account was charged twice', top_k=5)
results[['similarity', 'Product', 'Issue', 'Company', 'Complaint ID', 'text_transformer']]

# %% [markdown]
# ## Try Your Own Query

# %%
query = 'The bank closed my account and will not return my money'
search(query, top_k=5)

# %% [markdown]
# ## Build Commands
#
# Build the default 10k local index:
#
# ```bash
# python -m src.pipelines.phase4_build_embeddings --max-rows 10000 --batch-size 64
# ```
#
# Search from the CLI:
#
# ```bash
# python -m src.retrieval.semantic_search --query 'My account was charged twice' --top-k 5
# ```
