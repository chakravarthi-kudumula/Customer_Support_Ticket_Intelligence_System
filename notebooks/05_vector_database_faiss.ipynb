# %% [markdown]
# # Phase 5: Vector Database System
#
# This notebook documents the FAISS vector index used for semantic complaint retrieval.

# %% [markdown]
# ## Goal
#
# Store the 90k SBERT complaint embeddings in a vector index and retrieve similar complaints using cosine similarity. Because embeddings are normalized, FAISS inner product is equivalent to cosine similarity.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
manifest = json.loads((ROOT / 'artifacts/vector_indexes/latest_faiss_manifest.json').read_text())
manifest

# %%
benchmark = pd.read_csv(ROOT / 'artifacts/reports/phase5_vector_index_benchmark.csv')
benchmark

# %%
from src.retrieval.faiss_search import search

results = search("My account was charged twice", top_k=5)
results[['rank', 'similarity', 'search_ms', 'Product', 'Issue', 'Company', 'Complaint ID']]
