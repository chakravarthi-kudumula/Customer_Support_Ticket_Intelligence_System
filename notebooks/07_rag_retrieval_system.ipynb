# %% [markdown]
# # Phase 7: RAG-Style Retrieval
#
# This notebook checks the retrieval-grounded assistant built on SBERT, FAISS, context snippets, and complaint ID citations.

# %% [markdown]
# ## Scope
#
# This phase does not use a paid LLM. The answer is built from retrieved complaint context, so it stays close to the evidence.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
examples = pd.read_csv(ROOT / 'artifacts/reports/phase7_rag_examples.csv')
examples

# %%
from src.rag.retrieval_assistant import answer_query

result = answer_query("My bank charged me twice for the same transaction", top_k=3)
print(result["answer"])

# %% [markdown]
# ## Review Checklist
#
# - Does the answer cite complaint IDs?
# - Is the confidence score reasonable?
# - Are the snippets relevant to the query?
# - Does the answer avoid claims outside the retrieved complaints?
