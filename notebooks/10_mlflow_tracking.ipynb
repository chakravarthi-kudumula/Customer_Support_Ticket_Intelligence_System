# %% [markdown]
# # Phase 10: MLflow Experiment Tracking
#
# This notebook is a lightweight companion for the Phase 10 tracking pipeline. The actual logging logic lives in `src/pipelines/phase10_track_experiments.py`.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
PROJECT_ROOT

# %% [markdown]
# Run the tracking pipeline from the project root.

# %%
# !python -m src.pipelines.phase10_track_experiments

# %% [markdown]
# Open the MLflow UI after the pipeline has created `mlflow.db`.

# %%
# !mlflow ui --backend-store-uri sqlite:///mlflow.db --host 127.0.0.1 --port 5000

# %%
report_path = PROJECT_ROOT / "artifacts" / "reports" / "phase10_mlflow_tracking_report.md"
print(report_path.read_text() if report_path.exists() else "Run the Phase 10 pipeline first.")
