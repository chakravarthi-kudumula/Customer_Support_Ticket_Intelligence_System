# %% [markdown]
# # Phase 6: Complaint Summarization
#
# Generate executive summaries for long CFPB complaint narratives using a pretrained seq2seq transformer.

# %% [markdown]
# ## Why Zero-Shot?
#
# The CFPB dataset contains complaint narratives but no human-written target summaries, so Phase 6 uses pretrained summarization instead of supervised fine-tuning.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
examples = pd.read_csv(ROOT / 'artifacts/reports/phase6_summary_examples.csv')
examples[['Complaint ID', 'Product', 'input_word_count', 'summary_word_count', 'compression_ratio', 'was_truncated', 'summary']]

# %%
from src.summarization.complaint_summarizer import ComplaintSummarizer, SummaryConfig

summarizer = ComplaintSummarizer(SummaryConfig(local_files_only=True))
result = summarizer.summarize("My bank charged my account twice for the same transaction and has not refunded the duplicate charge after several calls.")
result

# %% [markdown]
# ## Review Criteria
#
# - Does the summary preserve the customer problem?
# - Does it avoid adding unsupported facts?
# - Is it short enough for an executive/support workflow?
# - Was the input truncated because of the model context window?
